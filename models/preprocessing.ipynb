# %% [markdown]
# <b>PART-I<b>

# %% [markdown]
# <b>Preprocessing of raw_wheat.csv to wheat.csv<b>

# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
#import missingno as msno
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline

# %%
daily_Data= pd.read_csv(r"C:\Users\rishi\yieldify\data\raw_wheat.csv")

# %%
daily_Data.head(2)
# Out:
#    Unnamed: 0  Sl_no District Name Market Name Commodity Variety Grade  \
# 0          34     35      Bhatinda    Bathinda     Wheat   Other   FAQ
# 1          33     34      Bhatinda    Bathinda     Wheat   Other   FAQ
#
#    Min_Price  Max Price (Rs./Quintal)  Modal_Price  Price_Date
# 0       1100                     1100         1100  2010-04-06
# 1       1100                     1100         1100  2010-04-07

# %%
daily_Data.shape
# Out:
# (351, 11)

# %%
df=daily_Data.copy()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sl_no', 'District Name', 'Market Name', 'Commodity',
#        'Variety', 'Grade', 'Min_Price', 'Max Price (Rs./Quintal)',
#        'Modal_Price', 'Price_Date'],
#       dtype='object')

# %%
df=df.rename(index=str, columns={"Sl no.": "Sl_no", "Min Price (Rs./Quintal)": "Min_Price","Price Date":"Price_Date","Modal Price (Rs./Quintal)":"Modal_Price"})

# %%
df.head()
# Out:
#    Unnamed: 0  Sl_no District Name Market Name Commodity Variety Grade  \
# 0          34     35      Bhatinda    Bathinda     Wheat   Other   FAQ
# 1          33     34      Bhatinda    Bathinda     Wheat   Other   FAQ
# 2          31     32      Bhatinda    Bathinda     Wheat   Other   FAQ
# 3          30     31      Bhatinda    Bathinda     Wheat   Other   FAQ
# 4        1644   1645      Bhatinda      Sangat     Wheat   Other   FAQ
#
#    Min_Price  Max Price (Rs./Quintal)  Modal_Price  Price_Date
# 0       1100                     1100         1100  2010-04-06
# 1       1100                     1100         1100  2010-04-07
# 2       1100                     1100         1100  2010-04-08
# 3       1100                     1100         1100  2010-04-09
# 4       1100                     1100         1100  2010-04-10

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sl_no', 'District Name', 'Market Name', 'Commodity',
#        'Variety', 'Grade', 'Min_Price', 'Max Price (Rs./Quintal)',
#        'Modal_Price', 'Price_Date'],
#       dtype='object')

# %%
df.Price_Date = pd.to_datetime(df.Price_Date, errors='coerce')

# %%
df.head()
# Out:
#    Unnamed: 0  Sl_no District Name Market Name Commodity Variety Grade  \
# 0          34     35      Bhatinda    Bathinda     Wheat   Other   FAQ
# 1          33     34      Bhatinda    Bathinda     Wheat   Other   FAQ
# 2          31     32      Bhatinda    Bathinda     Wheat   Other   FAQ
# 3          30     31      Bhatinda    Bathinda     Wheat   Other   FAQ
# 4        1644   1645      Bhatinda      Sangat     Wheat   Other   FAQ
#
#    Min_Price  Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0       1100                     1100         1100 2010-04-06
# 1       1100                     1100         1100 2010-04-07
# 2       1100                     1100         1100 2010-04-08
# 3       1100                     1100         1100 2010-04-09
# 4       1100                     1100         1100 2010-04-10

# %%
df=df.sort_values(by='Price_Date')

# %%
df.drop_duplicates('Price_Date', inplace = True)

# %%
df.head(20)
# Out:
#     Unnamed: 0  Sl_no District Name              Market Name Commodity  \
# 0           34     35      Bhatinda                 Bathinda     Wheat
# 1           33     34      Bhatinda                 Bathinda     Wheat
# 2           31     32      Bhatinda                 Bathinda     Wheat
# 3           30     31      Bhatinda                 Bathinda     Wheat
# 4         1644   1645      Bhatinda                   Sangat     Wheat
# 5          962    963      Bhatinda             Rampura Phul     Wheat
# 6          960    961      Bhatinda             Rampura Phul     Wheat
# 7         1618   1619      Bhatinda                   Sangat     Wheat
# 8         1064   1065      Bhatinda  Rampuraphul(Bhai Rupan)     Wheat
# 9         1061   1062      Bhatinda  Rampuraphul(Bhai Rupan)     Wheat
# 10          23     24      Bhatinda                 Bathinda     Wheat
# 11        1783   1784      Bhatinda            Talwandi Sabo     Wheat
# 12        1149   1150      Bhatinda      Rampuraphul(Chowke)     Wheat
# 13         304    305      Bhatinda                   Bhucho     Wheat
# 14        1556   1557      Bhatinda                   Sangat     Wheat
# 15        1546   1547      Bhatinda                   Sangat     Wheat
# 16         276    277      Bhatinda                   Bhucho     Wheat
# 17          13     14      Bhatinda                 Bathinda     Wheat
# 18         258    259      Bhatinda                   Bhucho     Wheat
# 19         249    250      Bhatinda                   Bhucho     Wheat
#
#    Variety Grade  Min_Price  Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0    Other   FAQ       1100                     1100         1100 2010-04-06
# 1    Other   FAQ       1100                     1100         1100 2010-04-07
# 2    Other   FAQ       1100                     1100         1100 2010-04-08
# 3    Other   FAQ       1100                     1100         1100 2010-04-09
# 4    Other   FAQ       1100                     1100         1100 2010-04-10
# 5    Other   FAQ       1100                     1100         1100 2010-04-11
# 6    Other   FAQ       1100                     1100         1100 2010-04-12
# 7    Other   FAQ       1100                     1100         1100 2010-04-13
# 8    Other   FAQ       1100                     1100         1100 2010-04-14
# 9    Other   FAQ       1100                     1100         1100 2010-04-15
# 10   Other   FAQ       1100                     1100         1100 2010-04-16
# 11   Other   FAQ       1100                     1100         1100 2010-04-17
# 12   Other   FAQ       1100                     1100         1100 2010-04-18
# 13   Kanak   FAQ       1100                     1100         1100 2010-04-19
# 14   Other   FAQ       1100                     1105         1100 2010-04-20
# 15   Other   FAQ       1100                     1105         1100 2010-04-21
# 16   Kanak   FAQ       1100                     1100         1100 2010-04-22
# 17   Other   FAQ       1100                     1100         1100 2010-04-23
# 18   Kanak   FAQ       1100                     1100         1100 2010-04-24
# 19   Kanak   FAQ       1100                     1100         1100 2010-04-25

# %% [markdown]
# <b>Saving to wheat.csv for future price prediction<b>

# %%
df.to_csv(r"C:\Users\rishi\yieldify\data\wheat.csv", sep=',')
